# %% [markdown]
# # Exercise 02 -  OLAP Cubes - Grouping Sets

# %% [markdown]
# Start by connecting to the database by running the cells below. If you are coming back to this exercise, then uncomment and run the first cell to recreate the database. If you recently completed the slicing and dicing exercise, then skip to the second cell.

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila_star
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila_star -f Data/pagila-star.sql

# %% [markdown]
# ### Connect to the local database where Pagila is loaded

# %%
import sql
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila_star'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila_star
# 'Connected: student@pagila_star'

# %% [markdown]
# ### Star Schema

# %% [markdown]
# <img src="pagila-star.png" width="50%"/>

# %% [markdown]
# # Grouping Sets
# - It happens often that for 3 dimensions, you want to aggregate a fact:
#     - by nothing (total)
#     - then by the 1st dimension
#     - then by the 2nd
#     - then by the 3rd
#     - then by the 1st and 2nd
#     - then by the 2nd and 3rd
#     - then by the 1st and 3rd
#     - then by the 1st and 2nd and 3rd
#
# - Since this is very common, and in all cases, we are iterating through all the fact table anyhow, there is a more clever way to do that using the SQL grouping statement "GROUPING SETS"

# %% [markdown]
# ## Total Revenue
#
# TODO: Write a query that calculates total revenue (sales_amount)

# %%
# %%sql
# SELECT sum(sales_amount) as revenue
# FROM factsales
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 1 rows affected.
# [(134833.020000063,)]

# %% [markdown]
# ## Revenue by Country
# TODO: Write a query that calculates total revenue (sales_amount) by country

# %%
# %%sql
# SELECT  ds.country, sum(f.sales_amount) AS revenue
# FROM factsales f
# JOIN dimcustomer ds ON f.customer_key = ds.customer_key
# GROUP BY ds.country
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 108 rows affected.
# [('Cambodia', 382.940000000001),
#  ('Turkey', 3324.23999999994),
#  ('Germany', 1662.08),
#  ('Chad', 271.36),
#  ('Madagascar', 187.56),
#  ('France', 748.080000000001),
#  ('Iraq', 223.46),
#  ('Colombia', 1418.82),
#  ('Japan', 6941.49999999975),
#  ('American Samoa', 143.6),
#  ('Virgin Islands, U.S.', 245.36),
#  ('Vietnam', 1492.56),
#  ('Kuwait', 223.48),
#  ('Ecuador', 780.260000000001),
#  ('Nepal', 233.56),
#  ('Cameroon', 400.920000000001),
#  ('Saudi Arabia', 1047.58),
#  ('Bangladesh', 804.100000000001),
#  ('Lithuania', 147.52),
#  ('Netherlands', 1173.32),
#  ('Yugoslavia', 518.860000000001),
#  ('Gambia', 259.4),
#  ('Nigeria', 3022.95999999995),
#  ('Dominican Republic', 636.460000000001),
#  ('Faroe Islands', 229.44),
#  ('Egypt', 1388.78),
#  ('Zambia', 269.34),
#  ('United States', 8240.53999999969),
#  ('Argentina', 2868.95999999996),
#  ('Slovakia', 179.48),
#  ('Angola', 430.960000000001),
#  ('Russian Federation', 6091.7399999998),
#  ('Oman', 375.000000000001),
#  ('Turkmenistan', 273.46),
#  ('Afghanistan', 135.64),
#  ('Czech Republic', 267.42),
#  ('Liechtenstein', 229.44),
#  ('Ethiopia', 183.54),
#  ('Azerbaijan', 490.860000000001),
#  ('Brazil', 6401.03999999978),
#  ('Israel', 844.020000000001),
#  ('Senegal', 201.5),
#  ('Chile', 656.580000000001),
#  ('New Zealand', 185.52),
#  ('Hungary', 223.42),
#  ('Mozambique', 688.400000000001),
#  ('Mexico', 6614.07999999977),
#  ('Finland', 203.48),
#  ('Taiwan', 2419.89999999998),
#  ('Sri Lanka', 233.4),
#  ('Thailand', 838.080000000001),
#  ('Estonia', 231.4),
#  ('Latvia', 524.800000000001),
#  ('Venezuela', 1366.6),
#  ('Peru', 937.760000000002),
#  ('Holy See (Vatican City State)', 305.32),
#  ('Runion', 433.08),
#  ('Anguilla', 213.3),
#  ('Bahrain', 225.5),
#  ('Algeria', 766.200000000001),
#  ('Malaysia', 738.300000000001),
#  ('Iran', 1901.5),
#  ('Spain', 1213.16),
#  ('Ukraine', 1460.84),
#  ('Tonga', 147.64),
#  ('South Korea', 1149.3),
#  ('Belarus', 554.680000000001),
#  ('French Guiana', 207.56),
#  ('Hong Kong', 285.4),
#  ('Malawi', 247.44),
#  ('Nauru', 297.38),
#  ('Romania', 470.760000000001),
#  ('North Korea', 227.38),
#  ('Puerto Rico', 508.780000000001),
#  ('Canada', 1187.26),
#  ('China', 11597.4799999995),
#  ('Austria', 614.440000000001),
#  ('Moldova', 255.32),
#  ('South Africa', 2408.29999999998),
#  ('Kenya', 506.920000000001),
#  ('Poland', 1755.94),
#  ('Kazakstan', 396.960000000001),
#  ('United Kingdom', 1845.62),
#  ('Brunei', 227.3),
#  ('Tunisia', 157.54),
#  ('Italy', 1662.22),
#  ('Pakistan', 1051.44),
#  ('Sweden', 289.32),
#  ('Armenia', 237.5),
#  ('Greece', 464.920000000001),
#  ('India', 13256.5599999994),
#  ('Yemen', 1021.66),
#  ('Paraguay', 550.760000000001),
#  ('Myanmar', 388.960000000001),
#  ('Philippines', 4762.63999999986),
#  ('Morocco', 614.580000000001),
#  ('Greenland', 275.32),
#  ('Switzerland', 504.780000000001),
#  ('Indonesia', 3020.65999999995),
#  ('Tuvalu', 241.48),
#  ('Saint Vincent and the Grenadines', 193.5),
#  ('Bolivia', 367.06),
#  ('Congo, The Democratic Republic of the', 425.000000000001),
#  ('Sudan', 454.920000000001),
#  ('United Arab Emirates', 666.320000000001),
#  ('Tanzania', 682.340000000001),
#  ('French Polynesia', 470.920000000001),
#  ('Bulgaria', 409.000000000001)]

# %% [markdown]
# ## Revenue by Month
# TODO: Write a query that calculates total revenue (sales_amount) by month

# %%
# %%sql
# SELECT dd.month, sum(f.sales_amount) AS revenue
# FROM factsales f
# JOIN dimdate dd ON f.date_key = dd.date_key
# GROUP BY dd.month
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 5 rows affected.
# [(1, 9648.8599999996),
#  (3, 47773.1199999983),
#  (4, 57118.9199999937),
#  (2, 19263.7600000004),
#  (5, 1028.36)]

# %% [markdown]
# ## Revenue by Month & Country
# TODO: Write a query that calculates total revenue (sales_amount) by month and country. Sort the data by month, country, and revenue in descending order. The first few rows of your output should match the table below.

# %%
# %%sql
# SELECT dd.month, ds.country, sum(f.sales_amount) AS revenue
# FROM factsales f
# JOIN dimdate dd ON f.date_key = dd.date_key
# JOIN dimcustomer ds ON f.customer_key = ds.customer_key
# GROUP BY dd.month, ds.country
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 484 rows affected.
# [(1, 'Virgin Islands, U.S.', 1.98),
#  (4, 'Morocco', 201.48),
#  (2, 'Bahrain', 61.9),
#  (1, 'Zambia', 25.94),
#  (2, 'Oman', 65.84),
#  (1, 'Latvia', 25.94),
#  (1, 'United Kingdom', 147.68),
#  (2, 'Iraq', 25.94),
#  (2, 'Egypt', 243.46),
#  (5, 'United Arab Emirates', 9.98),
#  (3, 'Finland', 91.78),
#  (3, 'Chile', 299.4),
#  (4, 'Greece', 181.62),
#  (5, 'Mexico', 27.88),
#  (2, 'Mozambique', 29.9),
#  (3, 'Morocco', 253.44),
#  (1, 'China', 911.820000000002),
#  (1, 'Faroe Islands', 13.98),
#  (1, 'Gambia', 29.94),
#  (1, 'Russian Federation', 450.800000000001),
#  (1, 'Malaysia', 61.88),
#  (3, 'Greece', 165.6),
#  (4, 'Chile', 203.54),
#  (4, 'Finland', 65.8),
#  (1, 'Congo, The Democratic Republic of the', 87.84),
#  (3, 'Sri Lanka', 93.76),
#  (2, 'Armenia', 25.96),
#  (3, 'Vietnam', 556.700000000001),
#  (2, 'Thailand', 127.68),
#  (3, 'Philippines', 1811.96),
#  (3, 'India', 5090.47999999985),
#  (3, 'Anguilla', 89.74),
#  (3, 'Holy See (Vatican City State)', 115.76),
#  (2, 'Dominican Republic', 67.82),
#  (4, 'Liechtenstein', 99.7),
#  (5, 'Germany', 29.9),
#  (3, 'South Korea', 355.28),
#  (1, 'Turkey', 241.46),
#  (2, 'Saint Vincent and the Grenadines', 31.92),
#  (2, 'Paraguay', 69.8),
#  (3, 'American Samoa', 15.92),
#  (1, 'Peru', 81.82),
#  (4, 'Bangladesh', 327.22),
#  (1, 'Nauru', 9.98),
#  (1, 'Italy', 103.78),
#  (2, 'Kuwait', 73.84),
#  (3, 'Iran', 700.440000000001),
#  (4, 'Israel', 407.080000000001),
#  (1, 'Tanzania', 37.9),
#  (4, 'United States', 3334.35999999994),
#  (2, 'Nigeria', 355.2),
#  (3, 'Liechtenstein', 57.88),
#  (4, 'South Korea', 582.620000000001),
#  (4, 'Anguilla', 75.72),
#  (4, 'Holy See (Vatican City State)', 93.74),
#  (2, 'Indonesia', 478.840000000001),
#  (4, 'Philippines', 1857.3),
#  (4, 'India', 5514.91999999982),
#  (2, 'Venezuela', 281.36),
#  (4, 'Vietnam', 616.620000000001),
#  (4, 'Sri Lanka', 91.76),
#  (3, 'United States', 3042.87999999995),
#  (2, 'Sudan', 55.8),
#  (4, 'Iran', 820.100000000001),
#  (3, 'Israel', 243.4),
#  (3, 'Bangladesh', 309.28),
#  (1, 'Azerbaijan', 41.94),
#  (5, 'Hungary', 1.98),
#  (4, 'American Samoa', 79.78),
#  (2, 'Chad', 19.96),
#  (5, 'United Kingdom', 23.92),
#  (2, 'Iran', 259.3),
#  (3, 'Kuwait', 107.74),
#  (4, 'Sudan', 211.52),
#  (3, 'Nigeria', 1085.54),
#  (5, 'Latvia', 5.98),
#  (4, 'Chad', 97.78),
#  (3, 'Saint Vincent and the Grenadines', 35.88),
#  (5, 'Zambia', 1.98),
#  (3, 'Paraguay', 183.56),
#  (2, 'American Samoa', 47.9),
#  (4, 'Venezuela', 584.540000000001),
#  (2, 'India', 1665.84),
#  (2, 'Philippines', 718.340000000001),
#  (4, 'Indonesia', 1213.22),
#  (2, 'Holy See (Vatican City State)', 83.86),
#  (2, 'Anguilla', 33.9),
#  (1, 'Mexico', 526.740000000001),
#  (3, 'Dominican Republic', 269.3),
#  (2, 'South Korea', 109.68),
#  (2, 'Sri Lanka', 21.94),
#  (3, 'Armenia', 63.86),
#  (2, 'Vietnam', 233.48),
#  (3, 'Thailand', 295.36),
#  (1, 'United Arab Emirates', 25.9),
#  (5, 'China', 81.74),
#  (4, 'Saint Vincent and the Grenadines', 93.76),
#  (4, 'Paraguay', 293.44),
#  (3, 'Chad', 127.7),
#  (2, 'United States', 1184.94),
#  (4, 'Nigeria', 1294.86),
#  (3, 'Sudan', 137.7),
#  (4, 'Kuwait', 29.94),
#  (2, 'Israel', 107.78),
#  (1, 'Pakistan', 103.76),
#  (2, 'Bangladesh', 121.72),
#  (4, 'Thailand', 367.16),
#  (4, 'Armenia', 141.7),
#  (5, 'Malaysia', 1.98),
#  (2, 'Liechtenstein', 41.9),
#  (4, 'Dominican Republic', 271.4),
#  (5, 'Russian Federation', 15.92),
#  (3, 'Indonesia', 1045.26),
#  (5, 'Faroe Islands', 1.98),
#  (1, 'Poland', 109.78),
#  (3, 'Venezuela', 438.900000000001),
#  (1, 'Germany', 179.6),
#  (3, 'Mozambique', 209.48),
#  (2, 'Finland', 37.92),
#  (2, 'Chile', 103.74),
#  (5, 'Tanzania', 9.98),
#  (3, 'Oman', 85.78),
#  (5, 'Italy', 7.96),
#  (3, 'Iraq', 63.82),
#  (3, 'Egypt', 512.800000000001),
#  (5, 'Peru', 9.98),
#  (3, 'Bahrain', 35.92),
#  (5, 'Turkey', 21.94),
#  (2, 'Greece', 59.88),
#  (1, 'Angola', 55.86),
#  (4, 'Mozambique', 391.12),
#  (4, 'Bahrain', 113.72),
#  (2, 'Morocco', 83.8),
#  (5, 'Azerbaijan', 1.98),
#  (4, 'Egypt', 562.700000000001),
#  (4, 'Iraq', 131.72),
#  (4, 'Oman', 161.52),
#  (2, 'French Polynesia', 37.9),
#  (4, 'Estonia', 55.84),
#  (2, 'Switzerland', 61.88),
#  (2, 'Ukraine', 159.6),
#  (4, 'Senegal', 49.86),
#  (1, 'Tuvalu', 53.92),
#  (4, 'Greenland', 117.7),
#  (2, 'Algeria', 121.76),
#  (5, 'Puerto Rico', 1.98),
#  (4, 'Brunei', 119.62),
#  (3, 'Moldova', 91.78),
#  (1, 'North Korea', 11.96),
#  (2, 'Taiwan', 343.2),
#  (4, 'Turkmenistan', 75.8),
#  (1, 'Madagascar', 1.98),
#  (3, 'Senegal', 89.8),
#  (1, 'Nepal', 31.94),
#  (3, 'Estonia', 103.72),
#  (1, 'Bolivia', 9.94),
#  (1, 'Yemen', 31.88),
#  (3, 'Turkmenistan', 107.84),
#  (2, 'Spain', 137.7),
#  (4, 'Moldova', 131.64),
#  (3, 'Brunei', 59.8),
#  (1, 'Malawi', 3.98),
#  (3, 'Greenland', 113.76),
#  (5, 'Canada', 7.96),
#  (4, 'Tunisia', 111.7),
#  (3, 'Sweden', 97.74),
#  (2, 'Colombia', 145.66),
#  (2, 'Japan', 977.660000000002),
#  (2, 'Bulgaria', 85.78),
#  (5, 'South Africa', 9.98),
#  (5, 'Belarus', 5.98),
#  (3, 'Kenya', 171.64),
#  (4, 'France', 399.1),
#  (4, 'New Zealand', 71.76),
#  (2, 'Cameroon', 67.82),
#  (1, 'Czech Republic', 1.98),
#  (2, 'Romania', 53.84),
#  (4, 'Sweden', 121.74),
#  (3, 'Tunisia', 33.88),
#  (1, 'Tonga', 17.96),
#  (5, 'Lithuania', 9.98),
#  (2, 'Kazakstan', 67.8),
#  (1, 'Cambodia', 23.92),
#  (3, 'New Zealand', 71.84),
#  (3, 'France', 161.52),
#  (1, 'Argentina', 163.56),
#  (4, 'Kenya', 195.58),
#  (1, 'Runion', 9.98),
#  (5, 'Brazil', 45.86),
#  (5, 'Netherlands', 1.98),
#  (5, 'Saudi Arabia', 7.96),
#  (1, 'Austria', 45.84),
#  (1, 'Ecuador', 41.9),
#  (2, 'Kenya', 117.78),
#  (4, 'Kazakstan', 193.52),
#  (3, 'Cameroon', 143.6),
#  (3, 'Bulgaria', 157.6),
#  (2, 'Sweden', 59.86),
#  (4, 'Romania', 239.38),
#  (3, 'Japan', 2506.05999999998),
#  (3, 'Colombia', 504.920000000001),
#  (1, 'Slovakia', 17.94),
#  (1, 'Puerto Rico', 31.9),
#  (5, 'Yemen', 5.98),
#  (5, 'Bolivia', 5.98),
#  (4, 'Bulgaria', 143.68),
#  (4, 'Cameroon', 147.62),
#  (3, 'Kazakstan', 123.7),
#  (1, 'French Guiana', 11.96),
#  (2, 'New Zealand', 27.94),
#  (2, 'France', 105.64),
#  (2, 'Tunisia', 9.98),
#  (4, 'Japan', 2835.25999999996),
#  (4, 'Colombia', 642.560000000001),
#  (3, 'Romania', 143.62),
#  (2, 'Moldova', 31.9),
#  (3, 'Taiwan', 797.880000000001),
#  (1, 'Yugoslavia', 51.88),
#  (4, 'Spain', 514.820000000001),
#  (1, 'Canada', 67.86),
#  (3, 'Algeria', 223.44),
#  (1, 'Myanmar', 29.9),
#  (3, 'French Polynesia', 183.62),
#  (3, 'Switzerland', 137.62),
#  (1, 'Belarus', 11.96),
#  (3, 'Ukraine', 494.880000000001),
#  (1, 'South Africa', 199.52),
#  (2, 'Brunei', 25.92),
#  (1, 'Lithuania', 19.96),
#  (2, 'Greenland', 7.98),
#  (4, 'Algeria', 341.2),
#  (2, 'Turkmenistan', 63.86),
#  (3, 'Spain', 426.980000000001),
#  (4, 'Taiwan', 1131.26),
#  (1, 'Netherlands', 51.88),
#  (4, 'Ukraine', 696.580000000001),
#  (1, 'Saudi Arabia', 131.74),
#  (4, 'Switzerland', 281.36),
#  (4, 'French Polynesia', 171.58),
#  (2, 'Estonia', 51.88),
#  (1, 'Brazil', 421.000000000001),
#  (5, 'Argentina', 53.82),
#  (2, 'Senegal', 51.86),
#  (5, 'Cambodia', 19.92),
#  (3, 'Russian Federation', 1919.36),
#  (5, 'Indonesia', 11.96),
#  (3, 'Faroe Islands', 89.78),
#  (3, 'Gambia', 117.74),
#  (5, 'Venezuela', 11.96),
#  (2, 'Angola', 71.84),
#  (3, 'Congo, The Democratic Republic of the', 189.54),
#  (3, 'Malaysia', 311.34),
#  (1, 'Greece', 55.84),
#  (4, 'Latvia', 253.4),
#  (4, 'United Kingdom', 760.200000000001),
#  (3, 'China', 4123.87999999989),
#  (2, 'Hungary', 49.9),
#  (4, 'Virgin Islands, U.S.', 137.64),
#  (4, 'Zambia', 109.72),
#  (4, 'Afghanistan', 75.84),
#  (1, 'Morocco', 65.88),
#  (5, 'Armenia', 5.98),
#  (4, 'Malaysia', 267.34),
#  (4, 'Congo, The Democratic Republic of the', 89.8),
#  (1, 'Finland', 7.98),
#  (1, 'Chile', 49.9),
#  (2, 'Hong Kong', 75.88),
#  (5, 'Thailand', 11.96),
#  (4, 'Faroe Islands', 101.76),
#  (4, 'Gambia', 89.76),
#  (2, 'Germany', 267.42),
#  (4, 'Russian Federation', 2853.77999999997),
#  (3, 'Afghanistan', 49.86),
#  (3, 'Zambia', 95.82),
#  (3, 'Virgin Islands, U.S.', 51.88),
#  (4, 'China', 4801.99999999986),
#  (3, 'United Kingdom', 552.560000000001),
#  (5, 'Nigeria', 17.94),
#  (3, 'Latvia', 141.68),
#  (5, 'Kuwait', 1.98),
#  (2, 'Pakistan', 163.62),
#  (4, 'Nauru', 121.74),
#  (4, 'Peru', 355.08),
#  (1, 'Bangladesh', 39.9),
#  (3, 'Azerbaijan', 175.58),
#  (1, 'United States', 620.580000000001),
#  (4, 'Tanzania', 291.36),
#  (4, 'Italy', 678.440000000001),
#  (1, 'Israel', 79.78),
#  (4, 'Turkey', 1484.54),
#  (2, 'Poland', 323.32),
#  (1, 'Liechtenstein', 29.96),
#  (3, 'Turkey', 1163.34),
#  (5, 'Bahrain', 5.98),
#  (1, 'Iran', 111.68),
#  (3, 'Italy', 628.520000000001),
#  (5, 'Oman', 9.98),
#  (3, 'Tanzania', 273.3),
#  (4, 'Azerbaijan', 219.5),
#  (3, 'Peru', 347.22),
#  (3, 'Nauru', 139.72),
#  (5, 'Iraq', 1.98),
#  (1, 'Vietnam', 67.82),
#  (2, 'United Arab Emirates', 127.66),
#  (1, 'Sri Lanka', 25.94),
#  (1, 'Holy See (Vatican City State)', 11.96),
#  (1, 'Anguilla', 13.94),
#  (2, 'Mexico', 1009.66),
#  (1, 'South Korea', 93.76),
#  (1, 'Philippines', 323.24),
#  (1, 'India', 859.780000000002),
#  (5, 'Greece', 1.98),
#  (4, 'United Arab Emirates', 323.24),
#  (1, 'Venezuela', 49.84),
#  (3, 'Poland', 544.600000000001),
#  (4, 'Mexico', 2773.57999999997),
#  (1, 'Indonesia', 271.38),
#  (1, 'Chad', 25.92),
#  (5, 'Morocco', 9.98),
#  (3, 'Pakistan', 417.000000000001),
#  (2, 'Azerbaijan', 51.86),
#  (1, 'Sudan', 49.9),
#  (1, 'Dominican Republic', 27.94),
#  (3, 'Mexico', 2276.21999999999),
#  (4, 'Poland', 778.240000000001),
#  (1, 'Thailand', 35.92),
#  (3, 'United Arab Emirates', 179.54),
#  (1, 'Kuwait', 9.98),
#  (2, 'Italy', 243.52),
#  (2, 'Tanzania', 69.8),
#  (1, 'Nigeria', 269.42),
#  (2, 'Peru', 143.66),
#  (2, 'Nauru', 25.94),
#  (4, 'Pakistan', 367.06),
#  (2, 'Turkey', 412.960000000001),
#  (1, 'Saint Vincent and the Grenadines', 31.94),
#  (1, 'Paraguay', 3.96),
#  (2, 'China', 1678.04),
#  (3, 'Hungary', 47.84),
#  (5, 'Israel', 5.98),
#  (5, 'United States', 57.78),
#  (5, 'Bangladesh', 5.98),
#  (4, 'Hong Kong', 99.76),
#  (3, 'Angola', 135.66),
#  (2, 'Congo, The Democratic Republic of the', 57.82),
#  (2, 'Malaysia', 95.76),
#  (2, 'Russian Federation', 851.880000000001),
#  (4, 'Germany', 652.420000000001),
#  (2, 'Faroe Islands', 21.94),
#  (2, 'Gambia', 21.96),
#  (2, 'United Kingdom', 361.26),
#  (1, 'Egypt', 69.82),
#  (1, 'Oman', 51.88),
#  (2, 'Latvia', 97.8),
#  (5, 'Iran', 9.98),
#  (2, 'Afghanistan', 9.94),
#  (1, 'Bahrain', 7.98),
#  (2, 'Zambia', 35.88),
#  (4, 'Hungary', 123.7),
#  (2, 'Virgin Islands, U.S.', 53.86),
#  (5, 'Philippines', 51.8),
#  (5, 'India', 125.54),
#  (5, 'South Korea', 7.96),
#  (3, 'Germany', 532.740000000001),
#  (1, 'Mozambique', 57.9),
#  (5, 'Vietnam', 17.94),
#  (3, 'Hong Kong', 109.76),
#  (4, 'Angola', 167.6),
#  (4, 'North Korea', 115.64),
#  (1, 'Turkmenistan', 19.98),
#  (1, 'Brunei', 11.98),
#  (2, 'Lithuania', 23.94),
#  (3, 'Malawi', 101.8),
#  (1, 'Greenland', 35.88),
#  (4, 'Tuvalu', 97.8),
#  (3, 'Madagascar', 111.76),
#  (1, 'Senegal', 9.98),
#  (3, 'Nepal', 85.86),
#  (1, 'Estonia', 19.96),
#  (3, 'Bolivia', 135.64),
#  (3, 'Yemen', 317.3),
#  (2, 'Brazil', 909.740000000002),
#  (2, 'Netherlands', 173.66),
#  (2, 'Saudi Arabia', 75.82),
#  (4, 'Malawi', 113.74),
#  (2, 'Myanmar', 95.74),
#  (2, 'Canada', 151.6),
#  (2, 'Ethiopia', 35.92),
#  (5, 'Colombia', 29.94),
#  (3, 'North Korea', 97.8),
#  (5, 'Japan', 45.82),
#  (2, 'Yugoslavia', 61.84),
#  (5, 'Bulgaria', 1.98),
#  (2, 'South Africa', 355.16),
#  (4, 'Bolivia', 127.72),
#  (4, 'Yemen', 524.860000000001),
#  (2, 'Belarus', 61.8),
#  (4, 'Nepal', 101.8),
#  (4, 'Madagascar', 47.88),
#  (3, 'Tuvalu', 65.82),
#  (5, 'Cameroon', 13.94),
#  (3, 'Argentina', 911.800000000002),
#  (1, 'France', 79.84),
#  (3, 'Cambodia', 61.78),
#  (1, 'New Zealand', 13.98),
#  (2, 'French Guiana', 25.96),
#  (3, 'Austria', 253.4),
#  (3, 'Runion', 175.64),
#  (3, 'Czech Republic', 91.82),
#  (5, 'Spain', 19.96),
#  (3, 'Tonga', 51.86),
#  (5, 'French Polynesia', 17.94),
#  (5, 'Switzerland', 15.96),
#  (4, 'Runion', 201.56),
#  (4, 'Austria', 235.42),
#  (4, 'Cambodia', 203.52),
#  (2, 'Ecuador', 109.8),
#  (1, 'Kenya', 15.94),
#  (4, 'Argentina', 1300.8),
#  (4, 'Tonga', 57.88),
#  (5, 'Algeria', 11.96),
#  (2, 'Puerto Rico', 65.84),
#  (5, 'Taiwan', 37.86),
#  (2, 'Slovakia', 33.92),
#  (1, 'Sweden', 9.98),
#  (4, 'Czech Republic', 141.68),
#  (4, 'Puerto Rico', 269.36),
#  (5, 'Brunei', 9.98),
#  (2, 'Tonga', 19.94),
#  (2, 'Czech Republic', 31.94),
#  (5, 'Turkmenistan', 5.98),
#  (1, 'Romania', 33.92),
#  (4, 'Slovakia', 85.76),
#  (2, 'Austria', 79.78),
#  (2, 'Runion', 45.9),
#  (2, 'Argentina', 438.980000000001),
#  (4, 'Ecuador', 333.22),
#  (1, 'Kazakstan', 11.94),
#  (2, 'Cambodia', 73.8),
#  (3, 'French Guiana', 93.82),
#  (1, 'Colombia', 95.74),
#  (1, 'Japan', 576.700000000001),
#  (3, 'Slovakia', 41.86),
#  (3, 'Puerto Rico', 139.7),
#  (4, 'French Guiana', 75.82),
#  (1, 'Cameroon', 27.94),
#  (3, 'Ecuador', 295.34),
#  (1, 'Bulgaria', 19.96),
#  (4, 'Belarus', 241.46),
#  (2, 'Bolivia', 87.78),
#  (3, 'Brazil', 2212.85999999999),
#  (2, 'Yemen', 141.64),
#  (4, 'South Africa', 935.680000000002),
#  (3, 'Netherlands', 472.920000000001),
#  (3, 'Saudi Arabia', 359.08),
#  (2, 'Madagascar', 25.94),
#  (2, 'Nepal', 13.96),
#  (5, 'France', 1.98),
#  (4, 'Canada', 440.880000000001),
#  (5, 'Tunisia', 1.98),
#  (4, 'Myanmar', 69.78),
#  (3, 'Lithuania', 39.84),
#  (2, 'Malawi', 27.92),
#  (1, 'Spain', 113.7),
#  (4, 'Yugoslavia', 257.46),
#  (4, 'Ethiopia', 47.84),
#  (2, 'Tuvalu', 23.94),
#  (5, 'Kenya', 5.98),
#  (1, 'Ukraine', 109.78),
#  (4, 'Saudi Arabia', 472.980000000001),
#  (3, 'South Africa', 907.960000000001),
#  (4, 'Netherlands', 472.880000000001),
#  (4, 'Brazil', 2811.57999999997),
#  (1, 'French Polynesia', 59.88),
#  (1, 'Switzerland', 7.96),
#  (3, 'Belarus', 233.48),
#  (3, 'Ethiopia', 99.78),
#  (1, 'Taiwan', 109.7),
#  (2, 'North Korea', 1.98),
#  (3, 'Yugoslavia', 147.68),
#  (1, 'Algeria', 67.84),
#  (4, 'Lithuania', 53.8),
#  (3, 'Myanmar', 193.54),
#  (3, 'Canada', 518.960000000001)]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>month</th>
#         <th>country</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Australia</td>
#         <td>2364.19</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Canada</td>
#         <td>2460.24</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Australia</td>
#         <td>4895.10</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Canada</td>
#         <td>4736.78</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Australia</td>
#         <td>12060.33</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## Revenue Total, by Month, by Country, by Month & Country All in one shot
#
# TODO: Write a query that calculates total revenue at the various grouping levels done above (total, by month, by country, by month & country) all at once using the grouping sets function. Your output should match the table below.

# %%
# %%sql
# SELECT dd.month, ds.country, sum(f.sales_amount) AS revenue
# FROM factsales f
# JOIN dimdate dd ON f.date_key = dd.date_key
# JOIN dimcustomer ds ON f.customer_key = ds.customer_key
# GROUP BY grouping sets((), dd.month, ds.country, (dd.month, ds.country))
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 598 rows affected.
# [(1, 'Algeria', 67.84),
#  (1, 'Angola', 55.86),
#  (1, 'Anguilla', 13.94),
#  (1, 'Argentina', 163.56),
#  (1, 'Austria', 45.84),
#  (1, 'Azerbaijan', 41.94),
#  (1, 'Bahrain', 7.98),
#  (1, 'Bangladesh', 39.9),
#  (1, 'Belarus', 11.96),
#  (1, 'Bolivia', 9.94),
#  (1, 'Brazil', 421.000000000001),
#  (1, 'Brunei', 11.98),
#  (1, 'Bulgaria', 19.96),
#  (1, 'Cambodia', 23.92),
#  (1, 'Cameroon', 27.94),
#  (1, 'Canada', 67.86),
#  (1, 'Chad', 25.92),
#  (1, 'Chile', 49.9),
#  (1, 'China', 911.820000000002),
#  (1, 'Colombia', 95.74),
#  (1, 'Congo, The Democratic Republic of the', 87.84),
#  (1, 'Czech Republic', 1.98),
#  (1, 'Dominican Republic', 27.94),
#  (1, 'Ecuador', 41.9),
#  (1, 'Egypt', 69.82),
#  (1, 'Estonia', 19.96),
#  (1, 'Faroe Islands', 13.98),
#  (1, 'Finland', 7.98),
#  (1, 'France', 79.84),
#  (1, 'French Guiana', 11.96),
#  (1, 'French Polynesia', 59.88),
#  (1, 'Gambia', 29.94),
#  (1, 'Germany', 179.6),
#  (1, 'Greece', 55.84),
#  (1, 'Greenland', 35.88),
#  (1, 'Holy See (Vatican City State)', 11.96),
#  (1, 'India', 859.780000000002),
#  (1, 'Indonesia', 271.38),
#  (1, 'Iran', 111.68),
#  (1, 'Israel', 79.78),
#  (1, 'Italy', 103.78),
#  (1, 'Japan', 576.700000000001),
#  (1, 'Kazakstan', 11.94),
#  (1, 'Kenya', 15.94),
#  (1, 'Kuwait', 9.98),
#  (1, 'Latvia', 25.94),
#  (1, 'Liechtenstein', 29.96),
#  (1, 'Lithuania', 19.96),
#  (1, 'Madagascar', 1.98),
#  (1, 'Malawi', 3.98),
#  (1, 'Malaysia', 61.88),
#  (1, 'Mexico', 526.740000000001),
#  (1, 'Morocco', 65.88),
#  (1, 'Mozambique', 57.9),
#  (1, 'Myanmar', 29.9),
#  (1, 'Nauru', 9.98),
#  (1, 'Nepal', 31.94),
#  (1, 'Netherlands', 51.88),
#  (1, 'New Zealand', 13.98),
#  (1, 'Nigeria', 269.42),
#  (1, 'North Korea', 11.96),
#  (1, 'Oman', 51.88),
#  (1, 'Pakistan', 103.76),
#  (1, 'Paraguay', 3.96),
#  (1, 'Peru', 81.82),
#  (1, 'Philippines', 323.24),
#  (1, 'Poland', 109.78),
#  (1, 'Puerto Rico', 31.9),
#  (1, 'Romania', 33.92),
#  (1, 'Runion', 9.98),
#  (1, 'Russian Federation', 450.800000000001),
#  (1, 'Saint Vincent and the Grenadines', 31.94),
#  (1, 'Saudi Arabia', 131.74),
#  (1, 'Senegal', 9.98),
#  (1, 'Slovakia', 17.94),
#  (1, 'South Africa', 199.52),
#  (1, 'South Korea', 93.76),
#  (1, 'Spain', 113.7),
#  (1, 'Sri Lanka', 25.94),
#  (1, 'Sudan', 49.9),
#  (1, 'Sweden', 9.98),
#  (1, 'Switzerland', 7.96),
#  (1, 'Taiwan', 109.7),
#  (1, 'Tanzania', 37.9),
#  (1, 'Thailand', 35.92),
#  (1, 'Tonga', 17.96),
#  (1, 'Turkey', 241.46),
#  (1, 'Turkmenistan', 19.98),
#  (1, 'Tuvalu', 53.92),
#  (1, 'Ukraine', 109.78),
#  (1, 'United Arab Emirates', 25.9),
#  (1, 'United Kingdom', 147.68),
#  (1, 'United States', 620.580000000001),
#  (1, 'Venezuela', 49.84),
#  (1, 'Vietnam', 67.82),
#  (1, 'Virgin Islands, U.S.', 1.98),
#  (1, 'Yemen', 31.88),
#  (1, 'Yugoslavia', 51.88),
#  (1, 'Zambia', 25.94),
#  (1, None, 9648.85999999961),
#  (2, 'Afghanistan', 9.94),
#  (2, 'Algeria', 121.76),
#  (2, 'American Samoa', 47.9),
#  (2, 'Angola', 71.84),
#  (2, 'Anguilla', 33.9),
#  (2, 'Argentina', 438.980000000001),
#  (2, 'Armenia', 25.96),
#  (2, 'Austria', 79.78),
#  (2, 'Azerbaijan', 51.86),
#  (2, 'Bahrain', 61.9),
#  (2, 'Bangladesh', 121.72),
#  (2, 'Belarus', 61.8),
#  (2, 'Bolivia', 87.78),
#  (2, 'Brazil', 909.740000000002),
#  (2, 'Brunei', 25.92),
#  (2, 'Bulgaria', 85.78),
#  (2, 'Cambodia', 73.8),
#  (2, 'Cameroon', 67.82),
#  (2, 'Canada', 151.6),
#  (2, 'Chad', 19.96),
#  (2, 'Chile', 103.74),
#  (2, 'China', 1678.04),
#  (2, 'Colombia', 145.66),
#  (2, 'Congo, The Democratic Republic of the', 57.82),
#  (2, 'Czech Republic', 31.94),
#  (2, 'Dominican Republic', 67.82),
#  (2, 'Ecuador', 109.8),
#  (2, 'Egypt', 243.46),
#  (2, 'Estonia', 51.88),
#  (2, 'Ethiopia', 35.92),
#  (2, 'Faroe Islands', 21.94),
#  (2, 'Finland', 37.92),
#  (2, 'France', 105.64),
#  (2, 'French Guiana', 25.96),
#  (2, 'French Polynesia', 37.9),
#  (2, 'Gambia', 21.96),
#  (2, 'Germany', 267.42),
#  (2, 'Greece', 59.88),
#  (2, 'Greenland', 7.98),
#  (2, 'Holy See (Vatican City State)', 83.86),
#  (2, 'Hong Kong', 75.88),
#  (2, 'Hungary', 49.9),
#  (2, 'India', 1665.84),
#  (2, 'Indonesia', 478.840000000001),
#  (2, 'Iran', 259.3),
#  (2, 'Iraq', 25.94),
#  (2, 'Israel', 107.78),
#  (2, 'Italy', 243.52),
#  (2, 'Japan', 977.660000000002),
#  (2, 'Kazakstan', 67.8),
#  (2, 'Kenya', 117.78),
#  (2, 'Kuwait', 73.84),
#  (2, 'Latvia', 97.8),
#  (2, 'Liechtenstein', 41.9),
#  (2, 'Lithuania', 23.94),
#  (2, 'Madagascar', 25.94),
#  (2, 'Malawi', 27.92),
#  (2, 'Malaysia', 95.76),
#  (2, 'Mexico', 1009.66),
#  (2, 'Moldova', 31.9),
#  (2, 'Morocco', 83.8),
#  (2, 'Mozambique', 29.9),
#  (2, 'Myanmar', 95.74),
#  (2, 'Nauru', 25.94),
#  (2, 'Nepal', 13.96),
#  (2, 'Netherlands', 173.66),
#  (2, 'New Zealand', 27.94),
#  (2, 'Nigeria', 355.2),
#  (2, 'North Korea', 1.98),
#  (2, 'Oman', 65.84),
#  (2, 'Pakistan', 163.62),
#  (2, 'Paraguay', 69.8),
#  (2, 'Peru', 143.66),
#  (2, 'Philippines', 718.340000000001),
#  (2, 'Poland', 323.32),
#  (2, 'Puerto Rico', 65.84),
#  (2, 'Romania', 53.84),
#  (2, 'Runion', 45.9),
#  (2, 'Russian Federation', 851.880000000001),
#  (2, 'Saint Vincent and the Grenadines', 31.92),
#  (2, 'Saudi Arabia', 75.82),
#  (2, 'Senegal', 51.86),
#  (2, 'Slovakia', 33.92),
#  (2, 'South Africa', 355.16),
#  (2, 'South Korea', 109.68),
#  (2, 'Spain', 137.7),
#  (2, 'Sri Lanka', 21.94),
#  (2, 'Sudan', 55.8),
#  (2, 'Sweden', 59.86),
#  (2, 'Switzerland', 61.88),
#  (2, 'Taiwan', 343.2),
#  (2, 'Tanzania', 69.8),
#  (2, 'Thailand', 127.68),
#  (2, 'Tonga', 19.94),
#  (2, 'Tunisia', 9.98),
#  (2, 'Turkey', 412.96),
#  (2, 'Turkmenistan', 63.86),
#  (2, 'Tuvalu', 23.94),
#  (2, 'Ukraine', 159.6),
#  (2, 'United Arab Emirates', 127.66),
#  (2, 'United Kingdom', 361.26),
#  (2, 'United States', 1184.94),
#  (2, 'Venezuela', 281.36),
#  (2, 'Vietnam', 233.48),
#  (2, 'Virgin Islands, U.S.', 53.86),
#  (2, 'Yemen', 141.64),
#  (2, 'Yugoslavia', 61.84),
#  (2, 'Zambia', 35.88),
#  (2, None, 19263.7600000004),
#  (3, 'Afghanistan', 49.86),
#  (3, 'Algeria', 223.44),
#  (3, 'American Samoa', 15.92),
#  (3, 'Angola', 135.66),
#  (3, 'Anguilla', 89.74),
#  (3, 'Argentina', 911.800000000002),
#  (3, 'Armenia', 63.86),
#  (3, 'Austria', 253.4),
#  (3, 'Azerbaijan', 175.58),
#  (3, 'Bahrain', 35.92),
#  (3, 'Bangladesh', 309.28),
#  (3, 'Belarus', 233.48),
#  (3, 'Bolivia', 135.64),
#  (3, 'Brazil', 2212.86),
#  (3, 'Brunei', 59.8),
#  (3, 'Bulgaria', 157.6),
#  (3, 'Cambodia', 61.78),
#  (3, 'Cameroon', 143.6),
#  (3, 'Canada', 518.960000000001),
#  (3, 'Chad', 127.7),
#  (3, 'Chile', 299.4),
#  (3, 'China', 4123.87999999989),
#  (3, 'Colombia', 504.920000000001),
#  (3, 'Congo, The Democratic Republic of the', 189.54),
#  (3, 'Czech Republic', 91.82),
#  (3, 'Dominican Republic', 269.3),
#  (3, 'Ecuador', 295.34),
#  (3, 'Egypt', 512.800000000001),
#  (3, 'Estonia', 103.72),
#  (3, 'Ethiopia', 99.78),
#  (3, 'Faroe Islands', 89.78),
#  (3, 'Finland', 91.78),
#  (3, 'France', 161.52),
#  (3, 'French Guiana', 93.82),
#  (3, 'French Polynesia', 183.62),
#  (3, 'Gambia', 117.74),
#  (3, 'Germany', 532.740000000001),
#  (3, 'Greece', 165.6),
#  (3, 'Greenland', 113.76),
#  (3, 'Holy See (Vatican City State)', 115.76),
#  (3, 'Hong Kong', 109.76),
#  (3, 'Hungary', 47.84),
#  (3, 'India', 5090.47999999985),
#  (3, 'Indonesia', 1045.26),
#  (3, 'Iran', 700.440000000001),
#  (3, 'Iraq', 63.82),
#  (3, 'Israel', 243.4),
#  (3, 'Italy', 628.520000000001),
#  (3, 'Japan', 2506.05999999998),
#  (3, 'Kazakstan', 123.7),
#  (3, 'Kenya', 171.64),
#  (3, 'Kuwait', 107.74),
#  (3, 'Latvia', 141.68),
#  (3, 'Liechtenstein', 57.88),
#  (3, 'Lithuania', 39.84),
#  (3, 'Madagascar', 111.76),
#  (3, 'Malawi', 101.8),
#  (3, 'Malaysia', 311.34),
#  (3, 'Mexico', 2276.21999999999),
#  (3, 'Moldova', 91.78),
#  (3, 'Morocco', 253.44),
#  (3, 'Mozambique', 209.48),
#  (3, 'Myanmar', 193.54),
#  (3, 'Nauru', 139.72),
#  (3, 'Nepal', 85.86),
#  (3, 'Netherlands', 472.920000000001),
#  (3, 'New Zealand', 71.84),
#  (3, 'Nigeria', 1085.54),
#  (3, 'North Korea', 97.8),
#  (3, 'Oman', 85.78),
#  (3, 'Pakistan', 417.000000000001),
#  (3, 'Paraguay', 183.56),
#  (3, 'Peru', 347.22),
#  (3, 'Philippines', 1811.96),
#  (3, 'Poland', 544.600000000001),
#  (3, 'Puerto Rico', 139.7),
#  (3, 'Romania', 143.62),
#  (3, 'Runion', 175.64),
#  (3, 'Russian Federation', 1919.36),
#  (3, 'Saint Vincent and the Grenadines', 35.88),
#  (3, 'Saudi Arabia', 359.08),
#  (3, 'Senegal', 89.8),
#  (3, 'Slovakia', 41.86),
#  (3, 'South Africa', 907.960000000002),
#  (3, 'South Korea', 355.28),
#  (3, 'Spain', 426.980000000001),
#  (3, 'Sri Lanka', 93.76),
#  (3, 'Sudan', 137.7),
#  (3, 'Sweden', 97.74),
#  (3, 'Switzerland', 137.62),
#  (3, 'Taiwan', 797.880000000001),
#  (3, 'Tanzania', 273.3),
#  (3, 'Thailand', 295.36),
#  (3, 'Tonga', 51.86),
#  (3, 'Tunisia', 33.88),
#  (3, 'Turkey', 1163.34),
#  (3, 'Turkmenistan', 107.84),
#  (3, 'Tuvalu', 65.82),
#  (3, 'Ukraine', 494.880000000001),
#  (3, 'United Arab Emirates', 179.54),
#  (3, 'United Kingdom', 552.560000000001),
#  (3, 'United States', 3042.87999999995),
#  (3, 'Venezuela', 438.900000000001),
#  (3, 'Vietnam', 556.700000000001),
#  (3, 'Virgin Islands, U.S.', 51.88),
#  (3, 'Yemen', 317.3),
#  (3, 'Yugoslavia', 147.68),
#  (3, 'Zambia', 95.82),
#  (3, None, 47773.1199999982),
#  (4, 'Afghanistan', 75.84),
#  (4, 'Algeria', 341.2),
#  (4, 'American Samoa', 79.78),
#  (4, 'Angola', 167.6),
#  (4, 'Anguilla', 75.72),
#  (4, 'Argentina', 1300.8),
#  (4, 'Armenia', 141.7),
#  (4, 'Austria', 235.42),
#  (4, 'Azerbaijan', 219.5),
#  (4, 'Bahrain', 113.72),
#  (4, 'Bangladesh', 327.22),
#  (4, 'Belarus', 241.46),
#  (4, 'Bolivia', 127.72),
#  (4, 'Brazil', 2811.57999999997),
#  (4, 'Brunei', 119.62),
#  (4, 'Bulgaria', 143.68),
#  (4, 'Cambodia', 203.52),
#  (4, 'Cameroon', 147.62),
#  (4, 'Canada', 440.880000000001),
#  (4, 'Chad', 97.78),
#  (4, 'Chile', 203.54),
#  (4, 'China', 4801.99999999986),
#  (4, 'Colombia', 642.560000000001),
#  (4, 'Congo, The Democratic Republic of the', 89.8),
#  (4, 'Czech Republic', 141.68),
#  (4, 'Dominican Republic', 271.4),
#  (4, 'Ecuador', 333.22),
#  (4, 'Egypt', 562.700000000001),
#  (4, 'Estonia', 55.84),
#  (4, 'Ethiopia', 47.84),
#  (4, 'Faroe Islands', 101.76),
#  (4, 'Finland', 65.8),
#  (4, 'France', 399.1),
#  (4, 'French Guiana', 75.82),
#  (4, 'French Polynesia', 171.58),
#  (4, 'Gambia', 89.76),
#  (4, 'Germany', 652.420000000001),
#  (4, 'Greece', 181.62),
#  (4, 'Greenland', 117.7),
#  (4, 'Holy See (Vatican City State)', 93.74),
#  (4, 'Hong Kong', 99.76),
#  (4, 'Hungary', 123.7),
#  (4, 'India', 5514.91999999982),
#  (4, 'Indonesia', 1213.22),
#  (4, 'Iran', 820.100000000001),
#  (4, 'Iraq', 131.72),
#  (4, 'Israel', 407.08),
#  (4, 'Italy', 678.440000000001),
#  (4, 'Japan', 2835.25999999996),
#  (4, 'Kazakstan', 193.52),
#  (4, 'Kenya', 195.58),
#  (4, 'Kuwait', 29.94),
#  (4, 'Latvia', 253.4),
#  (4, 'Liechtenstein', 99.7),
#  (4, 'Lithuania', 53.8),
#  (4, 'Madagascar', 47.88),
#  (4, 'Malawi', 113.74),
#  (4, 'Malaysia', 267.34),
#  (4, 'Mexico', 2773.57999999997),
#  (4, 'Moldova', 131.64),
#  (4, 'Morocco', 201.48),
#  (4, 'Mozambique', 391.12),
#  (4, 'Myanmar', 69.78),
#  (4, 'Nauru', 121.74),
#  (4, 'Nepal', 101.8),
#  (4, 'Netherlands', 472.880000000001),
#  (4, 'New Zealand', 71.76),
#  (4, 'Nigeria', 1294.86),
#  (4, 'North Korea', 115.64),
#  (4, 'Oman', 161.52),
#  (4, 'Pakistan', 367.060000000001),
#  (4, 'Paraguay', 293.44),
#  (4, 'Peru', 355.08),
#  (4, 'Philippines', 1857.3),
#  (4, 'Poland', 778.240000000001),
#  (4, 'Puerto Rico', 269.36),
#  (4, 'Romania', 239.38),
#  (4, 'Runion', 201.56),
#  (4, 'Russian Federation', 2853.77999999997),
#  (4, 'Saint Vincent and the Grenadines', 93.76),
#  (4, 'Saudi Arabia', 472.980000000001),
#  (4, 'Senegal', 49.86),
#  (4, 'Slovakia', 85.76),
#  (4, 'South Africa', 935.680000000002),
#  (4, 'South Korea', 582.620000000001),
#  (4, 'Spain', 514.820000000001),
#  (4, 'Sri Lanka', 91.76),
#  (4, 'Sudan', 211.52),
#  (4, 'Sweden', 121.74),
#  (4, 'Switzerland', 281.36),
#  (4, 'Taiwan', 1131.26),
#  (4, 'Tanzania', 291.36),
#  (4, 'Thailand', 367.16),
#  (4, 'Tonga', 57.88),
#  (4, 'Tunisia', 111.7),
#  (4, 'Turkey', 1484.54),
#  (4, 'Turkmenistan', 75.8),
#  (4, 'Tuvalu', 97.8),
#  (4, 'Ukraine', 696.580000000001),
#  (4, 'United Arab Emirates', 323.24),
#  (4, 'United Kingdom', 760.200000000001),
#  (4, 'United States', 3334.35999999994),
#  (4, 'Venezuela', 584.540000000001),
#  (4, 'Vietnam', 616.620000000001),
#  (4, 'Virgin Islands, U.S.', 137.64),
#  (4, 'Yemen', 524.860000000001),
#  (4, 'Yugoslavia', 257.46),
#  (4, 'Zambia', 109.72),
#  (4, None, 57118.9199999939),
#  (5, 'Algeria', 11.96),
#  (5, 'Argentina', 53.82),
#  (5, 'Armenia', 5.98),
#  (5, 'Azerbaijan', 1.98),
#  (5, 'Bahrain', 5.98),
#  (5, 'Bangladesh', 5.98),
#  (5, 'Belarus', 5.98),
#  (5, 'Bolivia', 5.98),
#  (5, 'Brazil', 45.86),
#  (5, 'Brunei', 9.98),
#  (5, 'Bulgaria', 1.98),
#  (5, 'Cambodia', 19.92),
#  (5, 'Cameroon', 13.94),
#  (5, 'Canada', 7.96),
#  (5, 'China', 81.74),
#  (5, 'Colombia', 29.94),
#  (5, 'Faroe Islands', 1.98),
#  (5, 'France', 1.98),
#  (5, 'French Polynesia', 17.94),
#  (5, 'Germany', 29.9),
#  (5, 'Greece', 1.98),
#  (5, 'Hungary', 1.98),
#  (5, 'India', 125.54),
#  (5, 'Indonesia', 11.96),
#  (5, 'Iran', 9.98),
#  (5, 'Iraq', 1.98),
#  (5, 'Israel', 5.98),
#  (5, 'Italy', 7.96),
#  (5, 'Japan', 45.82),
#  (5, 'Kenya', 5.98),
#  (5, 'Kuwait', 1.98),
#  (5, 'Latvia', 5.98),
#  (5, 'Lithuania', 9.98),
#  (5, 'Malaysia', 1.98),
#  (5, 'Mexico', 27.88),
#  (5, 'Morocco', 9.98),
#  (5, 'Netherlands', 1.98),
#  (5, 'Nigeria', 17.94),
#  (5, 'Oman', 9.98),
#  (5, 'Peru', 9.98),
#  (5, 'Philippines', 51.8),
#  (5, 'Puerto Rico', 1.98),
#  (5, 'Russian Federation', 15.92),
#  (5, 'Saudi Arabia', 7.96),
#  (5, 'South Africa', 9.98),
#  (5, 'South Korea', 7.96),
#  (5, 'Spain', 19.96),
#  (5, 'Switzerland', 15.96),
#  (5, 'Taiwan', 37.86),
#  (5, 'Tanzania', 9.98),
#  (5, 'Thailand', 11.96),
#  (5, 'Tunisia', 1.98),
#  (5, 'Turkey', 21.94),
#  (5, 'Turkmenistan', 5.98),
#  (5, 'United Arab Emirates', 9.98),
#  (5, 'United Kingdom', 23.92),
#  (5, 'United States', 57.78),
#  (5, 'Venezuela', 11.96),
#  (5, 'Vietnam', 17.94),
#  (5, 'Yemen', 5.98),
#  (5, 'Zambia', 1.98),
#  (5, None, 1028.36),
#  (None, None, 134833.020000063),
#  (None, 'Afghanistan', 135.64),
#  (None, 'Algeria', 766.200000000001),
#  (None, 'American Samoa', 143.6),
#  (None, 'Angola', 430.960000000001),
#  (None, 'Anguilla', 213.3),
#  (None, 'Argentina', 2868.95999999996),
#  (None, 'Armenia', 237.5),
#  (None, 'Austria', 614.440000000001),
#  (None, 'Azerbaijan', 490.860000000001),
#  (None, 'Bahrain', 225.5),
#  (None, 'Bangladesh', 804.100000000001),
#  (None, 'Belarus', 554.680000000001),
#  (None, 'Bolivia', 367.060000000001),
#  (None, 'Brazil', 6401.03999999978),
#  (None, 'Brunei', 227.3),
#  (None, 'Bulgaria', 409.0),
#  (None, 'Cambodia', 382.940000000001),
#  (None, 'Cameroon', 400.920000000001),
#  (None, 'Canada', 1187.26),
#  (None, 'Chad', 271.36),
#  (None, 'Chile', 656.580000000001),
#  (None, 'China', 11597.4799999995),
#  (None, 'Colombia', 1418.82),
#  (None, 'Congo, The Democratic Republic of the', 425.000000000001),
#  (None, 'Czech Republic', 267.42),
#  (None, 'Dominican Republic', 636.460000000001),
#  (None, 'Ecuador', 780.260000000001),
#  (None, 'Egypt', 1388.78),
#  (None, 'Estonia', 231.4),
#  (None, 'Ethiopia', 183.54),
#  (None, 'Faroe Islands', 229.44),
#  (None, 'Finland', 203.48),
#  (None, 'France', 748.080000000001),
#  (None, 'French Guiana', 207.56),
#  (None, 'French Polynesia', 470.920000000001),
#  (None, 'Gambia', 259.4),
#  (None, 'Germany', 1662.08),
#  (None, 'Greece', 464.920000000001),
#  (None, 'Greenland', 275.32),
#  (None, 'Holy See (Vatican City State)', 305.32),
#  (None, 'Hong Kong', 285.4),
#  (None, 'Hungary', 223.42),
#  (None, 'India', 13256.5599999994),
#  (None, 'Indonesia', 3020.65999999995),
#  (None, 'Iran', 1901.5),
#  (None, 'Iraq', 223.46),
#  (None, 'Israel', 844.020000000001),
#  (None, 'Italy', 1662.22),
#  (None, 'Japan', 6941.49999999975),
#  (None, 'Kazakstan', 396.960000000001),
#  (None, 'Kenya', 506.920000000001),
#  (None, 'Kuwait', 223.48),
#  (None, 'Latvia', 524.800000000001),
#  (None, 'Liechtenstein', 229.44),
#  (None, 'Lithuania', 147.52),
#  (None, 'Madagascar', 187.56),
#  (None, 'Malawi', 247.44),
#  (None, 'Malaysia', 738.300000000001),
#  (None, 'Mexico', 6614.07999999976),
#  (None, 'Moldova', 255.32),
#  (None, 'Morocco', 614.580000000001),
#  (None, 'Mozambique', 688.400000000001),
#  (None, 'Myanmar', 388.960000000001),
#  (None, 'Nauru', 297.38),
#  (None, 'Nepal', 233.56),
#  (None, 'Netherlands', 1173.32),
#  (None, 'New Zealand', 185.52),
#  (None, 'Nigeria', 3022.95999999995),
#  (None, 'North Korea', 227.38),
#  (None, 'Oman', 375.000000000001),
#  (None, 'Pakistan', 1051.44),
#  (None, 'Paraguay', 550.760000000001),
#  (None, 'Peru', 937.760000000002),
#  (None, 'Philippines', 4762.63999999986),
#  (None, 'Poland', 1755.94),
#  (None, 'Puerto Rico', 508.780000000001),
#  (None, 'Romania', 470.760000000001),
#  (None, 'Runion', 433.080000000001),
#  (None, 'Russian Federation', 6091.73999999979),
#  (None, 'Saint Vincent and the Grenadines', 193.5),
#  (None, 'Saudi Arabia', 1047.58),
#  (None, 'Senegal', 201.5),
#  (None, 'Slovakia', 179.48),
#  (None, 'South Africa', 2408.29999999999),
#  (None, 'South Korea', 1149.3),
#  (None, 'Spain', 1213.16),
#  (None, 'Sri Lanka', 233.4),
#  (None, 'Sudan', 454.920000000001),
#  (None, 'Sweden', 289.32),
#  (None, 'Switzerland', 504.780000000001),
#  (None, 'Taiwan', 2419.89999999998),
#  (None, 'Tanzania', 682.340000000001),
#  (None, 'Thailand', 838.080000000001),
#  (None, 'Tonga', 147.64),
#  (None, 'Tunisia', 157.54),
#  (None, 'Turkey', 3324.23999999994),
#  (None, 'Turkmenistan', 273.46),
#  (None, 'Tuvalu', 241.48),
#  (None, 'Ukraine', 1460.84),
#  (None, 'United Arab Emirates', 666.320000000001),
#  (None, 'United Kingdom', 1845.62),
#  (None, 'United States', 8240.53999999968),
#  (None, 'Venezuela', 1366.6),
#  (None, 'Vietnam', 1492.56),
#  (None, 'Virgin Islands, U.S.', 245.36),
#  (None, 'Yemen', 1021.66),
#  (None, 'Yugoslavia', 518.860000000001),
#  (None, 'Zambia', 269.34)]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>month</th>
#         <th>country</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Australia</td>
#         <td>2364.19</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>Canada</td>
#         <td>2460.24</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>None</td>
#         <td>4824.43</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Australia</td>
#         <td>4895.10</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>Canada</td>
#         <td>4736.78</td>
#     </tr>
#     <tr>
#         <td>2</td>
#         <td>None</td>
#         <td>9631.88</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Australia</td>
#         <td>12060.33</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>Canada</td>
#         <td>11826.23</td>
#     </tr>
#     <tr>
#         <td>3</td>
#         <td>None</td>
#         <td>23886.56</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>Australia</td>
#         <td>14136.07</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>Canada</td>
#         <td>14423.39</td>
#     </tr>
#     <tr>
#         <td>4</td>
#         <td>None</td>
#         <td>28559.46</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Australia</td>
#         <td>271.08</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>Canada</td>
#         <td>243.10</td>
#     </tr>
#     <tr>
#         <td>5</td>
#         <td>None</td>
#         <td>514.18</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>None</td>
#         <td>67416.51</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>Australia</td>
#         <td>33726.77</td>
#     </tr>
#     <tr>
#         <td>None</td>
#         <td>Canada</td>
#         <td>33689.74</td>
#     </tr>
# </tbody></table></div>
